# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/lambda's intro"
# Out:
# /content/drive/MyDrive/lambda's intro

# %%
# %ls
# Out:
#  anscombe_quartet_data.csv  'movies[1].csv'      pandas_manipulation.ipynb
#  company_sales_data.csv      mylesson1.ipynb     Untitled
# 'data[1].csv'                my_sales_data.png
#  house_pricing_dataset.csv   mysalesdata.png

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading our dataset

# %%
df = pd.read_csv('movies[1].csv')
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# ## Checking our dataset for missing values and the colums they belong too

# %%
df.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %% [markdown]
# ## Filling the Ratings columns empty rows with the mean value of the entire column

# %%
d = df['RATING'].mean()
rating =df['RATING'].fillna(d, inplace=True)

df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %% [markdown]
# ## Filling the Votes columns empty rows with 0 value of the entire column.
#
# this column cant be filled with the mean of the column seen as it is an object and not a numerical datatype

# %%
votes =df['VOTES'].fillna(0, inplace=True)

df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %% [markdown]
# ## Filling the Runtime columns empty rows with the mean value of the entire column seen as this has a numerical data type

# %%
b = df['RunTime'].mean()
votes =df['RunTime'].fillna(b, inplace=True)

df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %% [markdown]
# ## Filling the Gross columns empty rows with 0 values of the entire column

# %%
votes =df['Gross'].fillna(0, inplace=True)

df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %% [markdown]
# ## Checking to see which colums still has no values in them

# %%
df.isnull().sum()
# Out:
# MOVIES        0
# YEAR        644
# GENRE        80
# RATING        0
# ONE-LINE      0
# STARS         0
# VOTES         0
# RunTime       0
# Gross         0
# dtype: int64

# %% [markdown]
# ## drafting a heat map to help me check for missing values

# %%
sns.heatmap(df.isnull(), yticklabels=False, annot=True)

# %% [markdown]
# ## checking for duplicates
# this comes out with boolean values and doesnt really tells where all our duplicated values are or just how many duplicated rows there are, seen as this is a very large dataset

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994     True
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9999, dtype: bool

# %% [markdown]
# ## still checking for duplicates but using the .sum() to get the number of duplicated rows that we have

# %%
df.duplicated().sum()
# Out:
# 431

# %% [markdown]
# ## Dropping our duplicated values

# %%
df.drop_duplicates(inplace= True)

# %% [markdown]
# ## checking to see if we still have any duplicates in our dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Checking the data types of our columns

# %%
df.dtypes
# Out:
# MOVIES       object
# YEAR         object
# GENRE        object
# RATING      float64
# ONE-LINE     object
# STARS        object
# VOTES        object
# RunTime     float64
# Gross        object
# dtype: object

# %% [markdown]
# ## Dropping all rows that still has missing values to allow our dataset easy and ready to visualize

# %%
df.dropna( inplace = True)
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %% [markdown]
# ## Checking to see if we still have any missing values

# %%
my_values = df.isnull().sum()
print(my_values)
print('Our dataset is now ready for visualization')
# Out:
# MOVIES      0
# YEAR        0
# GENRE       0
# RATING      0
# ONE-LINE    0
# STARS       0
# VOTES       0
# RunTime     0
# Gross       0
# dtype: int64
# Our dataset is now ready for visualization
